# %%
# !git clone https://github.com/Rom0/BasicSR
# Out:
# Cloning into 'BasicSR'...
# remote: Enumerating objects: 4765, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 4765 (delta 21), reused 25 (delta 14), pack-reused 4720 (from 3)
# Receiving objects: 100% (4765/4765), 52.43 MiB | 31.84 MiB/s, done.
# Resolving deltas: 100% (3146/3146), done.

# %%
# %cd BasicSR
# Out:
# /content/BasicSR

# %%
#pretrained teacher #1
# !wget https://github.com/JingyunLiang/SwinIR/releases/download/v0.0/001_classicalSR_DF2K_s64w8_SwinIR-M_x2.pth
# Out:
# --2025-12-01 00:35:49--  https://github.com/JingyunLiang/SwinIR/releases/download/v0.0/001_classicalSR_DF2K_s64w8_SwinIR-M_x2.pth
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
#pretrained teacher #2
# !wget https://github.com/JingyunLiang/SwinIR/releases/download/v0.0/001_classicalSR_DIV2K_s48w8_SwinIR-M_x2.pth
# Out:
# --2025-12-01 00:35:52--  https://github.com/JingyunLiang/SwinIR/releases/download/v0.0/001_classicalSR_DIV2K_s48w8_SwinIR-M_x2.pth
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !pip install uv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.7/21.7 MB 115.8 MB/s eta 0:00:00
# ...

# %%
# !uv pip install -r requirements.txt
# Out:
# Using Python 3.12.12 environment at: /usr
# Resolved 55 packages in 434ms
# Prepared 4 packages in 110ms
# Installed 4 packages in 58ms
#  + addict==2.4.0
#  + lmdb==1.7.5
#  + tb-nightly==2.21.0a20251023
#  + yapf==0.43.0

# %%
#install cloned basicSR
# !uv pip install -e .
# Out:
# Using Python 3.12.12 environment at: /usr
# Resolved 28 packages in 188ms
# Prepared 3 packages in 1m 09s
# Uninstalled 2 packages in 73ms
# Installed 3 packages in 24ms
#  - absl-py==1.4.0
#  + absl-py==2.3.1
#  + basicsr==0.1.0 (from file:///content/BasicSR)
#  - numpy==2.0.2
#  + numpy==2.3.5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Training line

# %%
# !python -c "from basicsr.train import train_pipeline; train_pipeline('./')" \
    -opt swinir_x2_colab.yml
# Out:
# Disable distributed.
# pretrain_network path will be ignored during resuming.
# Set pretrain_network_g to ./experiments/DUKD_SwinIR_x2c180s36_c60s24/models/net_g_16000.pth
# 2025-11-26 20:24:34,891 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
#     / ____/____   ____   ____/ /  / /   __  __ _____ / /__   / /
#    / / __ / __ \ / __ \ / __  /  / /   / / / // ___// //_/  / /
#   / /_/ // /_/ // /_/ // /_/ /  / /___/ /_/ // /__ / /<    /_/
#   \____/ \____/ \____/ \____/  /_____/\____/ \___//_/|_|  (_)
#
# Version Information:
# 	BasicSR: 1.4.2
# 	PyTorch: 2.9.0+cu126
# 	TorchVision: 0.24.0+cu126
# 2025-11-26 20:24:34,891 INFO:
#   name: DUKD_SwinIR_x2c180s36_c60s24
# ...

# %% [markdown]
# #Test/inference line

# %% [markdown]
# must upload 22000.pth first since it gets ignored by .gitignore

# %%
#Inference
# !python -c "from basicsr.test import test_pipeline; test_pipeline('./')" -opt inference.yml
# Out:
# Disable distributed.
# Path already exists. Rename it to ./results/DUKD_SwinIR_x2c180s36_c60s24_archived_20251201_004303
# 2025-12-01 00:43:03,434 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
#     / ____/____   ____   ____/ /  / /   __  __ _____ / /__   / /
#    / / __ / __ \ / __ \ / __  /  / /   / / / // ___// //_/  / /
#   / /_/ // /_/ // /_/ // /_/ /  / /___/ /_/ // /__ / /<    /_/
#   \____/ \____/ \____/ \____/  /_____/\____/ \___//_/|_|  (_)
#
# Version Information:
# 	BasicSR: 1.4.2
# 	PyTorch: 2.9.0+cu126
# 	TorchVision: 0.24.0+cu126
# 2025-12-01 00:43:03,434 INFO:
#   name: DUKD_SwinIR_x2c180s36_c60s24
#   suffix: None
#   model_type: DUKD
#   scale: 2
# ...

# %% [markdown]
# # Pushing any changes to GitHub

# %%
from getpass import getpass
token = getpass("GitHub Token: ")
# Out:
# GitHub Token: ··········

# %%
# !git config --global user.name ""
# !git config --global user.email ""

# %%
# Add changes if any
# !git add -A
# Commit changes
# !git commit -m "Added checkpoints and pretrained model to speed up workflow"

# Push to your fork
# !git push https://Rom0:{token}@github.com/Rom0/BasicSR.git HEAD:master
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# Enumerating objects: 14, done.
# Counting objects: 100% (14/14), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (11/11), 46.01 MiB | 10.23 MiB/s, done.
# Total 11 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# remote: warning: See https://gh.io/lfs for more information.
# remote: warning: File 001_classicalSR_DF2K_s64w8_SwinIR-M_x2.pth is 64.16 MB; this is larger than GitHub's recommended maximum file size of 50.00 MB
# remote: warning: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# To https://github.com/Rom0/BasicSR.git
#    3a8bc59..4fa47cc  HEAD -> master

# %% [markdown]
# # Reloading any changes to the repo
# may need to redownload the pretrained model

# %%
#reset
# !git fetch origin
# !git reset --hard origin/master
# !pip install -e .
# Out:
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Total 6 (delta 5), reused 5 (delta 5), pack-reused 1 (from 1)
# Unpacking objects: 100% (6/6), 504 bytes | 252.00 KiB/s, done.
# From https://github.com/Rom0/BasicSR
#    3a8bc59..cc41d22  master     -> origin/master
# HEAD is now at cc41d22 Commented out padding removal for test
# Obtaining file:///content/BasicSR
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: basicsr
#     Found existing installation: basicsr 1.4.2
#     Uninstalling basicsr-1.4.2:
#       Successfully uninstalled basicsr-1.4.2
#   Running setup.py develop for basicsr
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-124314418.py in <cell line: 0>()
#       3 get_ipython().system('git reset --hard origin/master')
#       4 get_ipython().system('pip install -e .')
# ...

# %%
#may need to redownload the pretrained model
import importlib
import basicsr

importlib.reload(basicsr)
# Out:
# <module 'basicsr' from '/content/BasicSR/basicsr/__init__.py'>
